# %%
import pandas as pd

# %% [markdown]
# # Read TXT File

# %%
df = pd.read_csv("output.txt")

# %%
df.head(10)
# Out:
#                                nohup: ignoring input
# 0       tput: No value for $TERM and no -T specified
# 1  DataLoaderRaw loading images from folder: \t./...
# 2      listing all images in directory ./cv/images\t
# 3                 DataLoaderRaw found 37547 images\t
# 4     constructing clones inside the LanguageModel\t
# 5    cp "./cv/images/035669.jpg" vis/imgs/img1.jpg\t
# 6  image 1: a large clock tower towering over a c...
# 7     evaluating performance... 1/13000 (0.000000)\t
# 8    cp "./cv/images/036736.jpg" vis/imgs/img2.jpg\t
# 9  image 2: a woman is holding a cell phone in he...

# %%
df.tail(10)
# Out:
#                                    nohup: ignoring input
# 38996  cp "./cv/images/014450.jpg" vis/imgs/img12998....
# 38997  image 12998: a large clock tower towering over...
# 38998  evaluating performance... 12998/13000 (0.00000...
# 38999  cp "./cv/images/014080.jpg" vis/imgs/img12999....
# 39000  image 12999: a person holding a flower in a va...
# 39001  evaluating performance... 12999/13000 (0.00000...
# 39002  cp "./cv/images/014001.jpg" vis/imgs/img13000....
# 39003  image 13000: a person is sitting in front of a...
# 39004  evaluating performance... 13000/13000 (0.00000...
# 39005                                      loss: \tnan\t

# %% [markdown]
# # Remove redundant starting lines

# %%
def trim_lines(df, x=5):
    """ Removes first {x} rows from dataframe and the last row.
    """
    df = df.iloc[x:-1]
    return df

# %%
df = trim_lines(df)

# %%
df.head(5)
# Out:
#                                nohup: ignoring input
# 5    cp "./cv/images/035669.jpg" vis/imgs/img1.jpg\t
# 6  image 1: a large clock tower towering over a c...
# 7     evaluating performance... 1/13000 (0.000000)\t
# 8    cp "./cv/images/036736.jpg" vis/imgs/img2.jpg\t
# 9  image 2: a woman is holding a cell phone in he...

# %%
df.tail(5)
# Out:
#                                    nohup: ignoring input
# 39000  image 12999: a person holding a flower in a va...
# 39001  evaluating performance... 12999/13000 (0.00000...
# 39002  cp "./cv/images/014001.jpg" vis/imgs/img13000....
# 39003  image 13000: a person is sitting in front of a...
# 39004  evaluating performance... 13000/13000 (0.00000...

# %% [markdown]
# ### Adding column name

# %%
df.columns = ["original"]

# %% [markdown]
# # Removing evaluation

# %%
def label_evaluation(x):
    """ Needed for apply function
    """
    if "evaluating performance... " in x:
        return "yes"
    else:
        return "no"

# %%
def filter_evaluation(df):
    """ Filters evaluation lines
    """
    # label
    df["eval"] = df.original.apply(lambda x: label_evaluation(x))
    # filter
    df = df[df["eval"] == "no"]
    df = df.drop(["eval"], axis=1)
    return df

# %%
df = filter_evaluation(df)

# %%
df.head()
# Out:
#                                              original
# 5     cp "./cv/images/035669.jpg" vis/imgs/img1.jpg\t
# 6   image 1: a large clock tower towering over a c...
# 8     cp "./cv/images/036736.jpg" vis/imgs/img2.jpg\t
# 9   image 2: a woman is holding a cell phone in he...
# 11    cp "./cv/images/021069.jpg" vis/imgs/img3.jpg\t

# %% [markdown]
# # Extracting patahs, img names and caption

# %%
paths = list(df.iloc[::2, :].values)
paths = [path[0] for path in paths]
# paths

# %%
images = list(df.iloc[1:].iloc[::2, :].values)
# images = list(df.iloc[::1, :].values)
images = [img[0] for img in images]
# images

# %%
df = pd.DataFrame({
    "paths": paths,
    "images": images
})

# %%
df["caption"] = df.images.apply(lambda x: x.split(": ")[1].replace("\t",""))

# %%
df["path1"] = df.paths.apply(lambda x: x.split(" ")[1])
df["path2"] = df.paths.apply(lambda x: x.split(" ")[2])

# %%
df["name1"] = df.path1.apply(lambda x: x.split("/")[-1].strip('"'))
df["name2"] = df.path2.apply(lambda x: x.split("/")[-1].strip('\t"'))

# %%
df
# Out:
#                                                   images  \
# 0      image 1: a large clock tower towering over a c...
# 1      image 2: a woman is holding a cell phone in he...
# 2      image 3: a herd of animals grazing on a lush g...
# 3      image 4: a sign that says UNK UNK on the side ...
# 4      image 5: a couple of people that are in a field\t
# 5      image 6: a black and white photo of a person h...
# 6      image 7: a woman is standing on a sidewalk wit...
# 7      image 8: a street scene with focus on the side...
# 8      image 9: a bird is sitting on a branch of a tr...
# 9      image 10: a view of a mountain range from a pl...
# 10      image 11: a tree is in the middle of the water\t
# 11     image 12: a person is standing in front of a w...
# 12     image 13: a table with a vase of flowers and a...
# 13     image 14: a clock tower in the middle of a city\t
# 14     image 15: a person is standing in the rain wit...
# 15     image 16: a man and a woman walking down a str...
# 16     image 17: a man riding a skateboard down a str...
# 17        image 18: a large ship is docked in a harbor\t
# 18     image 19: a person holding a cell phone in the...
# 19           image 20: a man in a hat is holding a UNK\t
# 20     image 21: a picture of a person holding a remo...
# 21     image 22: a person sitting on the ground with ...
# 22      image 23: a pair of scissors on a wooden table\t
# 23       image 24: a person is holding a glass of wine\t
# 24     image 25: a bus is parked on the side of the s...
# 25     image 26: a vase filled with flowers on top of...
# 26          image 27: a close up of a bird on a branch\t
# 27     image 28: a dog and a dog are playing with a f...
# 28     image 29: a blender is on a table with a banana\t
# 29     image 30: a cat laying on the grass with a fri...
# ...                                                  ...
# 12970  image 12971: a plate of food with meat and veg...
# 12971  image 12972: an elephant is standing in the mi...
# 12972  image 12973: a park bench in the middle of a f...
# 12973  image 12974: a train station with a train on t...
# 12974  image 12975: a yellow bird is sitting on a bra...
# 12975  image 12976: a view of a city street from a wi...
# 12976  image 12977: a man holding a toothbrush in his...
# 12977  image 12978: a man standing in front of a trai...
# 12978  image 12979: a car is parked on the side of th...
# 12979  image 12980: a birthday cake with a UNK on the...
# 12980  image 12981: a close up of a person holding an...
# 12981  image 12982: a close up of a vase with flowers...
# 12982  image 12983: a picture of a man holding a cell...
# 12983  image 12984: a train traveling through a rural...
# 12984  image 12985: a large building with a clock on ...
# 12985  image 12986: a red bus is parked on the side o...
# 12986    image 12987: a view of a city street at night\t
# 12987  image 12988: a man in a suit and tie is holdin...
# 12988  image 12989: a train traveling over a bridge o...
# 12989  image 12990: a small bird sitting on a tree br...
# 12990  image 12991: a close up of a white and blue bi...
# 12991  image 12992: a bird standing on a rock in the ...
# 12992  image 12993: a red and white fire hydrant on t...
# 12993  image 12994: a view of a beach with a boat in ...
# 12994  image 12995: a bunch of different types of too...
# 12995  image 12996: a bunch of bananas on a wooden ta...
# 12996  image 12997: a dog standing on the side of a r...
# 12997  image 12998: a large clock tower towering over...
# 12998  image 12999: a person holding a flower in a va...
# 12999  image 13000: a person is sitting in front of a...
#
#                                                    paths  \
# 0        cp "./cv/images/035669.jpg" vis/imgs/img1.jpg\t
# 1        cp "./cv/images/036736.jpg" vis/imgs/img2.jpg\t
# 12989  cp "./cv/images/010537.jpg" vis/imgs/img12990....
# 12990  cp "./cv/images/008417.jpg" vis/imgs/img12991....
# 12991  cp "./cv/images/008237.jpg" vis/imgs/img12992....
# 12992  cp "./cv/images/032272.jpg" vis/imgs/img12993....
# 12993  cp "./cv/images/001482.jpg" vis/imgs/img12994....
# 12994  cp "./cv/images/020408.jpg" vis/imgs/img12995....
# 12995  cp "./cv/images/031326.jpg" vis/imgs/img12996....
# 12996  cp "./cv/images/012086.jpg" vis/imgs/img12997....
# 12997  cp "./cv/images/014450.jpg" vis/imgs/img12998....
# 12998  cp "./cv/images/014080.jpg" vis/imgs/img12999....
# 12999  cp "./cv/images/014001.jpg" vis/imgs/img13000....
#
#                                                  caption  \
# 0               a large clock tower towering over a city
# 1            a woman is holding a cell phone in her hand
# 2      a herd of animals grazing on a lush green hill...
# 3             a sign that says UNK UNK on the side of it
# 4                 a couple of people that are in a field
# 5      a black and white photo of a person holding an...
# 6      a woman is standing on a sidewalk with a cell ...
# 7      a street scene with focus on the side of the road
# 8                a bird is sitting on a branch of a tree
# 9                a view of a mountain range from a plane
# 10                  a tree is in the middle of the water
# 11             a person is standing in front of a window
# 12     a table with a vase of flowers and a vase of f...
# 13                 a clock tower in the middle of a city
# 14     a person is standing in the rain with an umbrella
# 15               a man and a woman walking down a street
# 16               a man riding a skateboard down a street
# 17                    a large ship is docked in a harbor
# 18           a person holding a cell phone in their hand
# 19                       a man in a hat is holding a UNK
# 20                a picture of a person holding a remote
# 21      a person sitting on the ground with a skateboard
# 22                  a pair of scissors on a wooden table
# 23                   a person is holding a glass of wine
# 24             a bus is parked on the side of the street
# 25          a vase filled with flowers on top of a table
# 26                      a close up of a bird on a branch
# 27            a dog and a dog are playing with a frisbee
# 28                 a blender is on a table with a banana
# 29     a cat laying on the grass with a frisbee in it...
# ...                                                  ...
# 12970           a plate of food with meat and vegetables
# 12971  an elephant is standing in the middle of a forest
# 12972             a park bench in the middle of a forest
# 12973         a train station with a train on the tracks
# 12974               a yellow bird is sitting on a branch
# 12975              a view of a city street from a window
# 12976            a man holding a toothbrush in his mouth
# 12977         a man standing in front of a train station
# 12978          a car is parked on the side of the street
# 12979        a birthday cake with a UNK on the top of it
# 12980            a close up of a person holding an apple
# 12981            a close up of a vase with flowers in it
# 12982            a picture of a man holding a cell phone
# 12983     a train traveling through a rural country side
# 12984                a large building with a clock on it
# 12985      a red bus is parked on the side of the street
# 12986                   a view of a city street at night
# 12987        a man in a suit and tie is holding a camera
# 12988       a train traveling over a bridge over a river
# 12989              a small bird sitting on a tree branch
# 12990                a close up of a white and blue bird
# 12991             a bird standing on a rock in the ocean
# 12992  a red and white fire hydrant on the side of th...
# 12993      a view of a beach with a boat in the distance
# 12994     a bunch of different types of tools on a table
# 12995               a bunch of bananas on a wooden table
# 12996              a dog standing on the side of a river
# 12997           a large clock tower towering over a city
# 12998                a person holding a flower in a vase
# 12999           a person is sitting in front of a mirror
#
#                           path1                    path2       name1  \
# 0      "./cv/images/035669.jpg"      vis/imgs/img1.jpg\t  035669.jpg
# 1      "./cv/images/036736.jpg"      vis/imgs/img2.jpg\t  036736.jpg
# 2      "./cv/images/021069.jpg"      vis/imgs/img3.jpg\t  021069.jpg
